# %% [markdown]
# # Preparing Artcollect data for pre-processing
# The Artcollect auction house data capturing process collects artwork information in JSON files.
# For further pre-processing some additional actions need to be taken:
# - Unify names of attributes, since they are not indentical for each auction house
# - Filter out non art related auctions, e.g. watches, cars etc (in particullar from Christie's)
# - set new index to 'key'
# - Save all data into one large file for further pre-processing

# %%
import numpy as np
import pandas as pd
import csv
from datetime import date

# %%
DATAPATH = "/Users/denizthemenace/dev/artcollect/data/"

# %% [markdown]
# ## Christie's clean-up
# ### Step 1: Concatenate Christie's datafiles to one DataFrame

# %%
lots_christies_1          = pd.read_json(DATAPATH + 'christies_1998-2005.json')
lots_christies_2          = pd.read_json(DATAPATH + 'christies_2006-2017.json')
lots_christies_raw        = pd.concat([lots_christies_1, lots_christies_2])

# %% [markdown]
# ### Step 2: Filter-out non art related auctions

# %%
# Read file containing names of art related auctions
with open(DATAPATH + 'christies_auctions_only_art_cleaned_up.csv', 'r') as f:
    reader = csv.reader(f)
    christies_only_art_auctions = list(reader)
    christies_only_art_auctions = [auction[0] for auction in christies_only_art_auctions]

print('# of Christie''s lots before filtering: ', len(lots_christies_raw))

# filter out auctions which aren't in the cleaned-up auction list
lots_christies_filtered = lots_christies_raw[lots_christies_raw['sale_title'].isin(christies_only_art_auctions)]
lots_christies_filtered.set_index('key', inplace=True)
print('# of Christie''s lots after  filtering: ', len(lots_christies_filtered))

# change name of auction_house_name column
lots_christies = lots_christies_filtered.copy()
lots_christies.loc[:,'auction_house'] = 'christies'
lots_christies.drop('auction_house_name', axis=1, inplace=True)

# change name of image_url column
lots_christies['image_urls'] = lots_christies['image_url']
lots_christies.drop('image_url', axis=1, inplace=True)
# Out:
# # of Christies lots before filtering:  927643
# # of Christies lots after  filtering:  232542

# %% [markdown]
# ## Phillips & Sotheby's clean-up

# %%
lots_phillips = pd.read_json(DATAPATH + 'phillips_all_lots_from_auction_pages_1-40.json')
lots_phillips.set_index('key', inplace=True)
lots_phillips['auction_house'] = 'phillips'
lots_phillips.drop('auction_house_name', axis=1, inplace=True)
print("# of Phillips lots after  filtering: ", len(lots_phillips))

lots_sothebys = pd.read_json(DATAPATH + 'sothebys.json')
lots_sothebys.set_index('key', inplace=True)
lots_sothebys['auction_house'] = 'sothebys'
lots_sothebys.drop('auction_house_name', axis=1, inplace=True)
print("# of Sotheby's lots after  filtering: ", len(lots_sothebys))
# Out:
# # of Phillips lots after  filtering:  64000
# # of Sotheby's lots after  filtering:  246362

# %% [markdown]
# ## Create one DataFrame containing all lots

# %%
lots_not_preprocessed = pd.concat([lots_christies, lots_phillips, lots_sothebys])
print("Total # of lots fro pre-processing:", len(lots_not_preprocessed))
# Out:
# Total # of lots fro pre-processing: 542904

# %% [markdown]
# ## Currency conversion to USD

# %%
lots_not_preprocessed['currency'].value_counts()
# Out:
# GBP    188886
# USD    153951
# EUR     65877
# HKD     43359
# CHF      3381
# NLG      2791
# AUD       959
# CAD       781
# SGD       430
# CNY       368
# RMB       319
# INR       128
# Name: currency, dtype: int64

# %% [markdown]
# ### Step 1: Convert prices to USD

# %%
def convert_to_usd_basic(row):
    '''Takes a lots dataframe as input and converts a price to USD'''
    
    exchange_rate = {'GBP': 0.747620,
                     'EUR': 0.848868,
                     'USD': 1.0,
                     'INR': 65.3090,
                     'JPY': 112.651,
                     'AUD': 1.27604,
                     'CAD': 1.24811,
                     'SGD': 1.35749,
                     'CHF': 0.969412,
                     'CNY': 6.65199,
                     'RMB': 6.65199,
                     'TWD': 30.3466,
                     'HKD': 7.81040,
                     'RUB': 57.5945,
                     'SKK': 8.17056,
                     'DKK': 6.31823,
                     'NLG': 1.87082,
                     'FRF': 5.56820,
                     'ITL': 1.64331,
                     'DEM': 1.65949,
                     'ESP': 141.173,
                    }
    try:
        return exchange_rate[row['currency']]
    except:
        return None

# create lots dataframe with USD prices only
lots_not_preprocessed_usd = lots_not_preprocessed.copy()

lots_not_preprocessed_usd['conversion_rate'] = \
                    lots_not_preprocessed_usd.apply(convert_to_usd_basic, axis=1)
lots_not_preprocessed_usd['price'] = \
                    lots_not_preprocessed_usd['price']/lots_not_preprocessed_usd['conversion_rate']
lots_not_preprocessed_usd['max_estimated_price'] = \
                    lots_not_preprocessed_usd['max_estimated_price']/lots_not_preprocessed_usd['conversion_rate']
lots_not_preprocessed_usd['min_estimated_price'] = \
                    lots_not_preprocessed_usd['min_estimated_price']/lots_not_preprocessed_usd['conversion_rate']

# %% [markdown]
# ### Step 2: Drop currency columns because all data is in USD now

# %%
#columns_to_drop = ['currency', 'estimate_currency', 'conversion_rate' ]
#lots_not_preprocessed_usd.drop(columns_to_drop, axis=1, inplace=True)

# %% [markdown]
# ## Run parsers

# %% [markdown]
# ### Step 1: artcollectParserLib imports

# %%
from artcollectParserLib.generic import parse_created_year, \
                                        parse_dimensions_and_convert_to_cm, \
                                        parse_height, \
                                        parse_width,\
                                        parse_size_unit, \
                                        parse_style

# %% [markdown]
# ### Step 2: Parse 'description' for created_year, style and dimensions

# %%
lots_not_preprocessed_usd['created_year'] = \
        lots_not_preprocessed_usd['description'].apply(parse_created_year)
lots_not_preprocessed_usd['height']       = \
        lots_not_preprocessed_usd['description'].apply(parse_dimensions_and_convert_to_cm).apply(parse_height)
lots_not_preprocessed_usd['width']        = \
        lots_not_preprocessed_usd['description'].apply(parse_dimensions_and_convert_to_cm).apply(parse_width)
lots_not_preprocessed_usd['size_unit']    = \
        lots_not_preprocessed_usd['description'].apply(parse_dimensions_and_convert_to_cm).apply(parse_size_unit)

# %%
def parse_style(text):
    '''Returns the style/media of an artwork
    
    Searches the input text for style/media related keywords from specific to generic and returns the first occurence
    
    Arguments:
        text including style/media information

    Returns:
        style/media
    '''
    if text:
        t = str(text).lower()
        if 'oil on canvas' in t: return 'oil painting'
        if 'oil on board' in t: return 'oil painting'
        if 'oil on paper' in t: return 'oil painting'
        if 'tempera on canvas' in t: return 'tempera painting'
        if 'tempera on board' in t: return 'tempera painting'
        if 'tempera on paper' in t: return 'tempera painting'
        if (('water' in t) and ('colo' in t)) or ('aquarel' in t) or ('gouache' in t): return 'watercolor painting'
        if 'acryllic on canvas' in t: return 'acryllic painting'
        if 'acryllic on board' in t: return 'acryllic painting'
        if 'acryllic on paper' in t: return 'acryllic painting'
        if 'drawing' in t: return 'drawing'
        if 'pastel' in t: return 'pastel'
        if 'lithograph' in t: return 'print'
        if 'etching' in t: return 'print'
        if 'screenprint' in t: return 'print'
        if 'photography' in t: return 'photography'
        if 'gelatin silver print' in t: return 'photography'
        if 'palladium print' in t: return 'photography'
        if 'platinum print' in t: return 'photography'
        if 'photogravure' in t: return 'photography'
        if 'bichromate print' in t: return 'photography'
        if 'chromogenic print' in t: return 'photography'
        if 'cibachrome' in t: return 'photography'
        if 'salt print' in t: return 'photography'
        if 'dye transfer print' in t: return 'photography'
        if 'albumen print' in t: return 'photography'
        if 'polaroid' in t: return 'photography'
        if 'print' in t: return 'print'
        if 'bronze' in t: return 'bronze'
        if 'marble' in t: return 'marble'
        if 'pen on paper' in t: return 'drawing'
        if 'ink on paper' in t: return 'drawing'

    return None

lots_not_preprocessed_usd['style']        = \
        lots_not_preprocessed_usd['description'].apply(parse_style)

# %%
lots_not_preprocessed_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 542904 entries, 2017-09-12T18-30-54-006900 to 2017-10-02T07-29-07-620207
# Data columns (total 30 columns):
# artist_name               458664 non-null object
# artist_name_normalized    458664 non-null object
# auction_house             542904 non-null object
# created_year              156351 non-null float64
# currency                  461230 non-null object
# description               540581 non-null object
# estimate_currency         541273 non-null object
# exhibited_in              75474 non-null object
# exhibited_in_museums      75503 non-null float64
# height                    327411 non-null float64
# image_urls                509868 non-null object
# images                    310362 non-null object
# lot_id                    539184 non-null float64
# max_estimated_price       460846 non-null float64
# min_estimated_price       460846 non-null float64
# notes                     172413 non-null object
# price                     461230 non-null float64
# provenance                252133 non-null object
# provenance_estate_of      252158 non-null float64
# sale_date                 540119 non-null object
# sale_id                   541039 non-null object
# sale_location             541362 non-null object
# sale_title                541546 non-null object
# secondary_title           212813 non-null object
# size_unit                 327411 non-null object
# style                     250778 non-null object
# title                     474387 non-null object
# url                       351616 non-null object
# width                     327411 non-null float64
# conversion_rate           461230 non-null float64
# dtypes: float64(10), object(20)
# memory usage: 128.4+ MB

# %%
styles_df = lots_not_preprocessed_usd[['auction_house', 'sale_title', 'style', 'description']]
styles_df.to_csv(DATAPATH + 'styles.json')

# %%
styles_df
# Out:
#                            auction_house  \
# key
# 2017-09-12T18-30-54-006900     christies
# 2017-09-12T18-30-54-047798     christies
# 2017-09-12T18-31-39-753728     christies
# 2017-09-12T18-38-28-970368     christies
# 2017-09-12T18-38-30-430791     christies
# 2017-09-12T18-38-30-539294     christies
# 2017-09-12T18-38-30-920099     christies
# 2017-09-12T18-38-31-330685     christies
# 2017-09-12T18-38-31-380693     christies
# 2017-09-12T18-38-31-584394     christies
# 2017-09-12T18-38-31-986032     christies
# 2017-09-12T18-38-32-161265     christies
# 2017-09-12T18-38-32-228030     christies
# 2017-09-12T18-38-32-283665     christies
# 2017-09-12T18-38-32-466825     christies
# 2017-09-12T18-38-32-529049     christies
# 2017-09-12T18-38-32-687165     christies
# 2017-09-12T18-38-32-852845     christies
# 2017-09-12T18-38-33-174273     christies
# 2017-09-12T18-38-33-357399     christies
# 2017-09-12T18-38-33-414061     christies
# 2017-09-12T18-38-33-464025     christies
# 2017-09-12T18-38-33-620103     christies
# 2017-09-12T18-38-33-722035     christies
# 2017-09-12T18-38-33-916081     christies
# 2017-09-12T18-38-34-201944     christies
# 2017-09-12T18-38-34-245030     christies
# 2017-09-12T18-38-34-297806     christies
# 2017-09-12T18-38-34-565744     christies
# 2017-09-12T18-38-34-759465     christies
# ...                                  ...
# 2017-10-02T07-28-45-115461      sothebys
# 2017-10-02T07-27-15-398455      sothebys
# 2017-10-02T07-24-16-468653      sothebys
# 2017-10-02T07-28-56-442484      sothebys
# 2017-10-02T07-24-37-895488      sothebys
# 2017-10-02T07-27-26-896082      sothebys
# 2017-10-02T07-29-04-924779      sothebys
# 2017-10-02T07-29-10-838528      sothebys
# 2017-10-02T07-27-31-919039      sothebys
# 2017-10-02T07-29-22-714021      sothebys
# 2017-10-02T07-29-20-872975      sothebys
# 2017-10-02T07-29-34-709757      sothebys
# 2017-10-02T07-29-32-173062      sothebys
# 2017-10-02T07-29-06-186593      sothebys
# 2017-10-02T07-28-51-916654      sothebys
# 2017-10-02T07-29-41-534911      sothebys
# 2017-10-02T07-26-59-686713      sothebys
# 2017-10-02T07-29-14-942550      sothebys
# 2017-10-02T07-29-40-245031      sothebys
# 2017-10-02T07-29-53-650316      sothebys
# 2017-10-02T07-28-40-688518      sothebys
# 2017-10-02T07-30-11-460955      sothebys
# 2017-10-02T07-31-03-608469      sothebys
# 2017-10-02T07-29-48-557942      sothebys
# 2017-10-02T07-29-11-642268      sothebys
# 2017-10-02T07-28-54-767120      sothebys
# 2017-10-02T07-29-53-272932      sothebys
# 2017-10-02T07-31-48-256538      sothebys
# 2017-10-02T07-31-45-991962      sothebys
# 2017-10-02T07-29-07-620207      sothebys
#
#                                                                    sale_title  \
# key
# 2017-09-12T18-30-54-006900                                   BRITISH PICTURES
# 2017-09-12T18-30-54-047798                                   BRITISH PICTURES
# 2017-09-12T18-31-39-753728                                   BRITISH PICTURES
# 2017-09-12T18-38-28-970368  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-30-430791  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-30-539294  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-30-920099  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-31-330685  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-31-380693  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-31-584394  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-31-986032  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-32-161265  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-32-228030  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-32-283665  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-32-466825  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-32-529049  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-32-687165  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-32-852845  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-33-174273  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-33-357399  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-33-414061  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-33-464025  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-33-620103  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-33-722035  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-33-916081  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-34-201944  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-34-245030  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-34-297806  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-34-565744  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# 2017-09-12T18-38-34-759465  OILS, WATERCOLOURS & DRAWINGS FROM 18TH - 20TH...
# ...                                                                       ...
# 2017-10-02T07-28-45-115461                Contemporary Literati — A Gathering
# 2017-10-02T07-27-15-398455                Contemporary Literati — A Gathering
# 2017-10-02T07-24-16-468653         Old Master Paintings and British Paintings
# 2017-10-02T07-28-56-442484                Contemporary Literati — A Gathering
# 2017-10-02T07-24-37-895488                Contemporary Literati — A Gathering
# 2017-10-02T07-27-26-896082                Contemporary Literati — A Gathering
# 2017-10-02T07-29-04-924779                Contemporary Literati — A Gathering
# 2017-10-02T07-29-10-838528                Contemporary Literati — A Gathering
# 2017-10-02T07-27-31-919039                Contemporary Literati — A Gathering
# 2017-10-02T07-29-22-714021                Contemporary Literati — A Gathering
# 2017-10-02T07-29-20-872975                Contemporary Literati — A Gathering
# 2017-10-02T07-29-34-709757                Contemporary Literati — A Gathering
# 2017-10-02T07-29-32-173062                Contemporary Literati — A Gathering
# 2017-10-02T07-29-06-186593                Contemporary Literati — A Gathering
# 2017-10-02T07-28-51-916654                Contemporary Literati — A Gathering
# 2017-10-02T07-29-41-534911                Contemporary Literati — A Gathering
# 2017-10-02T07-26-59-686713                Contemporary Literati — A Gathering
# 2017-10-02T07-29-14-942550                Contemporary Literati — A Gathering
# 2017-10-02T07-29-40-245031                Contemporary Literati — A Gathering
# 2017-10-02T07-29-53-650316                               Contemporary Curated
# 2017-10-02T07-28-40-688518                Contemporary Literati — A Gathering
# 2017-10-02T07-30-11-460955                Contemporary Literati — A Gathering
# 2017-10-02T07-31-03-608469                Contemporary Literati — A Gathering
# 2017-10-02T07-29-48-557942                Contemporary Literati — A Gathering
# 2017-10-02T07-29-11-642268                Contemporary Literati — A Gathering
# 2017-10-02T07-28-54-767120                Contemporary Literati — A Gathering
# 2017-10-02T07-29-53-272932                Contemporary Literati — A Gathering
# 2017-10-02T07-31-48-256538                Contemporary Literati — A Gathering
# 2017-10-02T07-31-45-991962                Contemporary Literati — A Gathering
# 2017-10-02T07-29-07-620207                Contemporary Literati — A Gathering
#
#                               style  \
# key
# 2017-09-12T18-30-54-006900     None
# 2017-09-12T18-30-54-047798     None
# 2017-09-12T18-31-39-753728     None
# 2017-09-12T18-38-28-970368     None
# 2017-09-12T18-38-30-430791     None
# 2017-09-12T18-38-30-539294     None
# 2017-09-12T18-38-30-920099     None
# 2017-09-12T18-38-31-330685     None
# 2017-09-12T18-38-31-380693     None
# 2017-09-12T18-38-31-584394     None
# 2017-09-12T18-38-31-986032     None
# 2017-09-12T18-38-32-161265     None
# 2017-09-12T18-38-32-228030     None
# 2017-09-12T18-38-32-283665     None
# 2017-09-12T18-38-32-466825     None
# 2017-09-12T18-38-32-529049     None
# 2017-09-12T18-38-32-687165     None
# 2017-09-12T18-38-32-852845     None
# 2017-09-12T18-38-33-174273     None
# 2017-09-12T18-38-33-357399     None
# 2017-09-12T18-38-33-414061     None
# 2017-09-12T18-38-33-464025     None
# 2017-09-12T18-38-33-620103     None
# 2017-09-12T18-38-33-722035     None
# 2017-09-12T18-38-33-916081     None
# 2017-09-12T18-38-34-201944     None
# 2017-09-12T18-38-34-245030     None
# 2017-09-12T18-38-34-297806     None
# 2017-09-12T18-38-34-565744     None
# 2017-09-12T18-38-34-759465     None
# ...                             ...
# 2017-10-02T07-28-45-115461     None
# 2017-10-02T07-27-15-398455     None
# 2017-10-02T07-24-16-468653     None
# 2017-10-02T07-28-56-442484     None
# 2017-10-02T07-24-37-895488     None
# 2017-10-02T07-27-26-896082     None
# 2017-10-02T07-29-04-924779     None
# 2017-10-02T07-29-10-838528     None
# 2017-10-02T07-27-31-919039     None
# 2017-10-02T07-29-22-714021  drawing
# 2017-10-02T07-29-20-872975     None
# 2017-10-02T07-29-34-709757     None
# 2017-10-02T07-29-32-173062     None
# 2017-10-02T07-29-06-186593     None
# 2017-10-02T07-28-51-916654     None
# 2017-10-02T07-29-41-534911     None
# 2017-10-02T07-26-59-686713     None
# 2017-10-02T07-29-14-942550     None
# 2017-10-02T07-29-40-245031  drawing
# 2017-10-02T07-29-53-650316     None
# 2017-10-02T07-28-40-688518     None
# 2017-10-02T07-30-11-460955     None
# 2017-10-02T07-31-03-608469     None
# 2017-10-02T07-29-48-557942     None
# 2017-10-02T07-29-11-642268     None
# 2017-10-02T07-28-54-767120     None
# 2017-10-02T07-29-53-272932     None
# 2017-10-02T07-31-48-256538     None
# 2017-10-02T07-31-45-991962     None
# 2017-10-02T07-29-07-620207     None
#
#                                                                         notes  \
# key
# 2017-09-12T18-30-54-006900                                                NaN
# 2017-09-12T18-30-54-047798                                                NaN
# 2017-09-12T18-31-39-753728                                                NaN
# 2017-09-12T18-38-28-970368  Alexander Pope was born in 1688, the son of a ...
# 2017-09-12T18-38-30-430791                                                NaN
# 2017-09-12T18-38-30-539294                                                NaN
# 2017-09-12T18-38-30-920099                                                NaN
# 2017-09-12T18-38-31-330685                                                NaN
# 2017-09-12T18-38-31-380693                                                NaN
# 2017-09-12T18-38-31-584394  This work looks east down Fleet Street towards...
# 2017-09-12T18-38-31-986032                                                NaN
# 2017-09-12T18-38-32-161265                                                NaN
# 2017-09-12T18-38-32-228030                                                NaN
# 2017-09-12T18-38-32-283665                                                NaN
# 2017-09-12T18-38-32-466825                                                NaN
# 2017-09-12T18-38-32-529049                                                NaN
# 2017-09-12T18-38-32-687165                                                NaN
# 2017-09-12T18-38-32-852845                                                NaN
# 2017-09-12T18-38-33-174273                                                NaN
# 2017-09-12T18-38-33-357399                                                NaN
# 2017-09-12T18-38-33-414061  The triangular lodge was built in 1593 by Sir ...
# 2017-09-12T18-38-33-464025                                                NaN
# 2017-09-12T18-38-33-620103                                                NaN
# 2017-09-12T18-38-33-722035                                                NaN
# 2017-09-12T18-38-33-916081                                                NaN
# 2017-09-12T18-38-34-201944                                                NaN
# 2017-09-12T18-38-34-245030                                                NaN
# 2017-09-12T18-38-34-297806                                                NaN
# 2017-09-12T18-38-34-565744  Owley is midway between Rye and Tenterden in S...
# 2017-09-12T18-38-34-759465  The 'Mechtilde' design was one of six linen fa...
# ...                                                                       ...
# 2017-10-02T07-28-45-115461                                                NaN
# 2017-10-02T07-27-15-398455                                                NaN
# 2017-10-02T07-24-16-468653  Probably painted towards the end of the 1520s,...
# 2017-10-02T07-28-56-442484                                                NaN
# 2017-10-02T07-24-37-895488                                                NaN
# 2017-10-02T07-27-26-896082                                                NaN
# 2017-10-02T07-29-04-924779                                                NaN
# 2017-10-02T07-29-10-838528                                                NaN
# 2017-10-02T07-27-31-919039  Please refer to Important Notices Concerning t...
# 2017-10-02T07-29-22-714021                                                NaN
# 2017-10-02T07-29-20-872975                                                NaN
# 2017-10-02T07-29-34-709757                                                NaN
# 2017-10-02T07-29-32-173062  Taihu rocks of this monumental size are extrem...
# 2017-10-02T07-29-06-186593  Please refer to Important Notices Concerning t...
# 2017-10-02T07-28-51-916654   \r\nStone sculptures of lions have traditiona...
# 2017-10-02T07-29-41-534911  This finely carved small head is closely relat...
# 2017-10-02T07-26-59-686713                                                NaN
# 2017-10-02T07-29-14-942550                                                NaN
# 2017-10-02T07-29-40-245031                                                NaN
# 2017-10-02T07-29-53-650316                                                NaN
# 2017-10-02T07-28-40-688518                                                NaN
# 2017-10-02T07-30-11-460955                                                NaN
# 2017-10-02T07-31-03-608469                                                NaN
# 2017-10-02T07-29-48-557942  Shao Can (1803-1862), also named Youcun, was a...
# 2017-10-02T07-29-11-642268                                                NaN
# 2017-10-02T07-28-54-767120                                                NaN
# 2017-10-02T07-29-53-272932  Screens were movable partitions that could pro...
# 2017-10-02T07-31-48-256538                                                NaN
# 2017-10-02T07-31-45-991962  Please refer to Important Notices Concerning t...
# 2017-10-02T07-29-07-620207                                                NaN
#
#                                                                   description
# key
# 2017-09-12T18-30-54-006900                             T. Henwood, circa 1850
# 2017-09-12T18-30-54-047798                        J.F. Marshall, 19th Century
# 2017-09-12T18-31-39-753728  Henry Weekes (fl.1851-1884) and Charles Dukes ...
# 2017-09-12T18-38-28-970368          Circle of Jonathon Richardson (1665-1745)
# 2017-09-12T18-38-30-430791                       John Piper, C.H. (1903-1992)
# 2017-09-12T18-38-30-539294                       John Piper, C.H. (1903-1992)
# 2017-09-12T18-38-30-920099                       John Piper, C.H. (1903-1992)
# 2017-09-12T18-38-31-330685           Charles Ernest Cundall, R.A. (1890-1971)
# 2017-09-12T18-38-31-380693                           Edward Seago (1910-1974)
# 2017-09-12T18-38-31-584394                 Robert McGown Coventry (1855-1914)
# 2017-09-12T18-38-31-986032                       John Piper, C.H. (1903-1992)
# 2017-09-12T18-38-32-161265                           Edward Seago (1910-1974)
# 2017-09-12T18-38-32-228030         Attributed to Henry Lamb, R.A. (1883-1960)
# 2017-09-12T18-38-32-283665                          Eliot Hodgkin (1905-1987)
# 2017-09-12T18-38-32-466825                            John Minton (1917-1957)
# 2017-09-12T18-38-32-529049                             Alan Reynolds (b.1926)
# 2017-09-12T18-38-32-687165                             Alan Reynolds (b.1926)
# 2017-09-12T18-38-32-852845                         Lionel Edwards (1878-1966)
# 2017-09-12T18-38-33-174273              Philip Wilson Steer, O.M. (1860-1942)
# 2017-09-12T18-38-33-357399                  George Denholm Armour (1864-1949)
# 2017-09-12T18-38-33-414061                        Stanley Roy Badmin (b.1906)
# 2017-09-12T18-38-33-464025                         Lionel Edwards (1878-1966)
# 2017-09-12T18-38-33-620103              Philip Wilson Steer, O.M. (1860-1942)
# 2017-09-12T18-38-33-722035              Philip Wilson Steer, O.M. (1860-1942)
# 2017-09-12T18-38-33-916081                            John Minton (1917-1957)
# 2017-09-12T18-38-34-201944                        Mortimer Menpes (1860-1938)
# 2017-09-12T18-38-34-245030                           Robert Bevan (1865-1925)
# 2017-09-12T18-38-34-297806                       John Piper, C.H. (1903-1992)
# 2017-09-12T18-38-34-565744                              Paul Nash (1889-1946)
# 2017-09-12T18-38-34-759465                              Roger Fry (1866-1933)
# ...                                                                       ...
# 2017-10-02T07-28-45-115461  the rectangular tabletop set with a burlwood f...
# 2017-10-02T07-27-15-398455  the tabletop with a framed two-board floating ...
# 2017-10-02T07-24-16-468653  oil on panel 108 by 80 cm.; 42 1/2  by 31 1/2 ...
# 2017-10-02T07-28-56-442484  the slightly tapered round stone fragment carv...
# 2017-10-02T07-24-37-895488  titled on the reverse and with one seal of the...
# 2017-10-02T07-27-26-896082  formed from a tree root section, naturalistica...
# 2017-10-02T07-29-04-924779  the tabletop with a framed single board termin...
# 2017-10-02T07-29-10-838528  formed from a large tree root section opening ...
# 2017-10-02T07-27-31-919039        circa 1935 28 by 75 cm., 11 by 29 1/2  in.
# 2017-10-02T07-29-22-714021  inscribed and with three seals of the artist i...
# 2017-10-02T07-29-20-872975  each signed Yu Hui, and with four seals of the...
# 2017-10-02T07-29-34-709757  sensitively carved with serene, naturalistic e...
# 2017-10-02T07-29-32-173062  vertically oriented, the highly resonant sound...
# 2017-10-02T07-29-06-186593  circa 1975 45 by 45 cm., 17 3/4  by 17 3/4  in.
# 2017-10-02T07-28-51-916654  carved seated on its haunches on a rectangular...
# 2017-10-02T07-29-41-534911  carved with a serene expression with beautific...
# 2017-10-02T07-26-59-686713  each with a hard seat secured to a pair of rou...
# 2017-10-02T07-29-14-942550  the shallow rounded sides rising from a flat b...
# 2017-10-02T07-29-40-245031  signed Jinling Liu Dan (Liu Dan from Nanjing),...
# 2017-10-02T07-29-53-650316  signed; signed, titled and dated x-S-10-64 on ...
# 2017-10-02T07-28-40-688518  the attenuated deep green stone of vertical or...
# 2017-10-02T07-30-11-460955  of square section with a slightly tapered body...
# 2017-10-02T07-31-03-608469  exquisitely wrought out to stand horizontally ...
# 2017-10-02T07-29-48-557942  naturalistically carved from a hollowed-out tr...
# 2017-10-02T07-29-11-642268  each signed Xiangzhou, with one seal of the ar...
# 2017-10-02T07-28-54-767120  each of hexagonal section, with a slightly rou...
# 2017-10-02T07-29-53-272932  naturalistically carved in openwork with intri...
# 2017-10-02T07-31-48-256538  formed from a single piece of stone, the low s...
# 2017-10-02T07-31-45-991962  circa 18th century 85 by 70 cm., 33 1/2  by 27...
# 2017-10-02T07-29-07-620207  signed Xiaosong, dated 2009, with one seal of ...
#
# [542904 rows x 5 columns]

# %%
lots_not_preprocessed_usd['style'].value_counts()
# Out:
# oil painting           40543
# watercolor painting    13860
# print                   7650
# drawing                 4596
# photography             3527
# pastel                  1784
# tempera painting         430
# Name: style, dtype: int64

# %% [markdown]
# ## Drop unneeded columns and incomplete rows

# %%
columns_to_drop = ['artist_name','image_urls','lot_id','notes','sale_location','secondary_title','url','size_unit','currency','estimate_currency','conversion_rate' ]
lots_not_preprocessed_usd.drop(columns_to_drop, axis=1, inplace=True)

rows_to_drop_if_nan_columns = [
                               'price',
                               'max_estimated_price',
                               'min_estimated_price',
                               'created_year',
                               'style']
lots_not_preprocessed_usd.dropna(subset=rows_to_drop_if_nan_columns, inplace=True)

# drop all artworks which aren't paintings
lots_not_preprocessed_usd = lots_not_preprocessed_usd[lots_not_preprocessed_usd['style'] != 'bronze']
lots_not_preprocessed_usd = lots_not_preprocessed_usd[lots_not_preprocessed_usd['style'] != 'marble']
lots_not_preprocessed_usd = lots_not_preprocessed_usd[lots_not_preprocessed_usd['created_year'] > 1499]
lots_not_preprocessed_usd = lots_not_preprocessed_usd[lots_not_preprocessed_usd['created_year'] < (date.today().year + 1)]

# %% [markdown]
# ## Split Train & Test

# %%
from math import floor
lots_not_preprocessed_usd['decade'] = lots_not_preprocessed_usd['created_year'].apply(lambda x: floor(x/10))

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size =0.2, random_state=42)
for train_index, test_index  in split.split(lots_not_preprocessed_usd, lots_not_preprocessed_usd['decade']):
    strat_train_set = lots_not_preprocessed_usd.iloc[train_index]
    strat_test_set  = lots_not_preprocessed_usd.iloc[test_index]
    
strat_train_set.drop('decade', axis=1, inplace=True)
strat_test_set.drop('decade', axis=1, inplace=True)
lots_not_preprocessed_usd.drop('decade', axis=1, inplace=True)
# Out:
# /Users/denizthemenace/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/denizthemenace/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# ## Save to file

# %%
lots_not_preprocessed_usd.to_json(DATAPATH + 'lots_not_preprocessed.json')
strat_train_set.to_json(DATAPATH + 'lots_train_set.json')
strat_train_set.to_json(DATAPATH + 'lots_test_set.json')

print('Saved', len(strat_train_set), 'stratified training lots in USD to', DATAPATH + 'lots_train_set.json')
print('Saved', len(strat_test_set), 'test lots to', DATAPATH + 'lots_test_set.json')
# Out:
# Saved 57912 stratified training lots in USD to /Users/denizthemenace/dev/artcollect/data/lots_train_set.json
# Saved 14478 test lots to /Users/denizthemenace/dev/artcollect/data/lots_test_set.json
